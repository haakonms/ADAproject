# %% [markdown]
# # Twitter trolls - how Russia meddles with western democracies
#
#
# ## Abstract
# Over the last several years there has been an attempt from Russian trolls to spread propaganda and fake news over social media in order to spread political ideas among the general population both nationally and internationally. Can these attempts be regarded as undermining the democracy of the affected countries?
#
# In this project we are going to analyze a great number of these russian tweets and look into their motivations for this meddling. We will mainly look into their overall political goals in the US, and examine how these goals change over time. Have the trolls achieved their goals? We will also look into how the trolls operate and organize themselves, trying to find patterns in the madness. Such patterns can hopefully help the general population to indicate that a tweet is originating from a troll. As the Russian efforts are increasing every year, a solution is needed to defend the democracy.
#
# ### Imports used in this notebook

# %%
import pandas as pd
import numpy as np
from zipfile import ZipFile
import scipy as sp
from pyspark.sql import *
import matplotlib.pyplot as plt
from statistics import median 
from langdetect import detect
# %matplotlib inline
from datetime import datetime
from pyspark.sql.functions import *
from pyspark.sql.types import *
from matplotlib.pyplot import figure
#import pyspark.sql.SQLContext
from ipywidgets import *
import pyspark.sql.functions as func
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# # 1) Preprocessing the data
# The data sets are of different shape and quality. The first one, provided by two researchers from Clemson University has already been preprocessed a bit. The second one is still quite raw, even though it has certain features as for example language. We have been cleaning some of it, and also processing and enriching to make new data frames that we want to use in our analysis.
#
# ## 1.1) The first dataset - IRA tweets from Kaggle.
# The first dataset has the following features:
# - external_author_id | An author account ID from Twitter
# - author | The handle sending the tweet
# - content | The text of the tweet
# - region | A region classification based on following criterias:
#      - 1. Geographical coordinates
#      - 2. Location listed in the user's profile
#      - 3. Time zone set by the user in their Twitter account settings.
# - language | The language of the tweet
# - publish_date | The date and time the tweet was sent
# - harvested_date | The date and time the tweet was collected by Social Studio
# - following | The number of accounts the handle was following at the time of the tweet
# - followers | The number of followers the handle had at the time of the tweet
# - updates | The number of “update actions” on the account that authored the tweet, including tweets, retweets and likes
# - post_type | Indicates if the tweet was a retweet or a quote-tweet
# - account_type | Specific account theme, as coded by Linvill and Warren
# - retweet | A binary indicator of whether or not the tweet is a retweet
# - account_category` | General account theme, as coded by Linvill and Warren
# - new_june_2018 | A binary indicator of whether the handle was newly listed in June 2018
#
#
# ### 1.1.1) Loading the first dataset
# We loaded the 9 files into a unified dataframe. We decided to use pandas, since the dataset is not too large, and especially with the fact that we will be focusing on subsets of these tweets.

# %%
zip_file = ZipFile('russian-troll-tweets.zip')
data = pd.DataFrame()
for i in range(1,9):
    data = data.append(pd.read_csv(zip_file.open("IRAhandle_tweets_"+str(i)+".csv")))
first_set_data=data.reset_index()
first_set_data.tail(5)
# Out:
#           index  external_author_id        author  \
# 2935811  378290        1.513801e+09  YOUJUSTCTRLC
# 2935812  378291        1.513801e+09  YOUJUSTCTRLC
# 2935813  378292        1.513801e+09  YOUJUSTCTRLC
# 2935814  378293        1.513801e+09  YOUJUSTCTRLC
# 2935815  378294        1.513801e+09  YOUJUSTCTRLC
#
#                                                    content         region  \
# 2935811  They'll say some shit anonymously like a cowar...  United States
# 2935812            Mr. Brown knees https://t.co/LmAiHCnFlz  United States
# 2935813  Like, you want somebody who follows you regula...  United States
# 2935814  If you wanna ask me something, ask it here so ...  United States
# 2935815  And there he is again ... Inside the KGB Playb...  United States
#
#         language   publish_date harvested_date  following  followers  updates  \
# 2935811  English  1/7/2017 7:47  1/7/2017 7:48       2655       2724     3007
# 2935812  English  1/7/2017 7:47  1/7/2017 7:48       2655       2724     3006
# 2935813  English  1/7/2017 7:47  1/7/2017 7:47       2655       2724     3005
# 2935814  English  1/7/2017 7:48  1/7/2017 7:48       2655       2724     3008
# 2935815  English  1/8/2017 1:56  1/8/2017 1:57       2655       2724     3013
#
#         post_type account_type  new_june_2018  retweet account_category
# 2935811   RETWEET         left              0        1        LeftTroll
# 2935812   RETWEET         left              0        1        LeftTroll
# 2935813   RETWEET         left              0        1        LeftTroll
# 2935814   RETWEET         left              0        1        LeftTroll
# 2935815   RETWEET         left              0        1        LeftTroll

# %%
first_set_data.head(5)
# Out:
#    index  external_author_id  author  \
# 0      0        9.060000e+17  10_GOP
# 1      1        9.060000e+17  10_GOP
# 2      2        9.060000e+17  10_GOP
# 3      3        9.060000e+17  10_GOP
# 4      4        9.060000e+17  10_GOP
#
#                                              content   region language  \
# 0  "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1  Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2  Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
# 3  JUST IN: President Trump dedicates Presidents ...  Unknown  English
# 4  19,000 RESPECTING our National Anthem! #StandF...  Unknown  English
#
#       publish_date   harvested_date  following  followers  updates post_type  \
# 0  10/1/2017 19:58  10/1/2017 19:59       1052       9636      253       NaN
# 1  10/1/2017 22:43  10/1/2017 22:43       1054       9637      254       NaN
# 2  10/1/2017 22:50  10/1/2017 22:51       1054       9637      255   RETWEET
# 3  10/1/2017 23:52  10/1/2017 23:52       1062       9642      256       NaN
# 4   10/1/2017 2:13   10/1/2017 2:13       1050       9645      246   RETWEET
#
#   account_type  new_june_2018  retweet account_category
# 0        Right              0        0       RightTroll
# 1        Right              0        0       RightTroll
# 2        Right              0        1       RightTroll
# 3        Right              0        0       RightTroll
# 4        Right              0        1       RightTroll

# %% [markdown]
# ### 1.1.2) Cleaning and filtering the first dataset
# The first dataset is pretty clean as it is, but it contains some nan-values and duplicates. We are also working with some parts of the data set, so it's filtered a bit as well.
#
# #### 1.1.2.1) Dropping the data we don't want.

# %% [markdown]
# The index column is unnecessary as pandas assigns an index anyway. "new_june_2018" and "harvested_date" does not add anything that we are going to use, and we already have a "post_type", so we don't need a binary indicator for that.

# %%
data1_drop_step = first_set_data.drop(columns=["retweet", "index", "new_june_2018", "harvested_date"])

# %% [markdown]
# #### 1.1.2.2) Filtering out the english tweets.
# After inspecting some of the tweets we concluded that a lot of the language stamps do not match the actual tweets. For instance, most of the tweets labeled to our mothertongue Norwegian was English. The same went for different languages, such as those of neighbouring countries like Danish and Swedish. For this reason we decide to discard all tweets in other languages than english, in order to avoid confusion. We could have included tweets in other languages of which we have some knowledge of, we decide not to as we have limited knowledge of the political climate in these countries. The labeling of english tweets are also better, and our decision also helps keeping the scope of the project limited.

# %%
data1_filter_english = data1_drop_step.loc[data1_drop_step['language'] == "English"]
data1_filter_english.head(3)
# Out:
#    external_author_id  author  \
# 0        9.060000e+17  10_GOP
# 1        9.060000e+17  10_GOP
# 2        9.060000e+17  10_GOP
#
#                                              content   region language  \
# 0  "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1  Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2  Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
#
#       publish_date  following  followers  updates post_type account_type  \
# 0  10/1/2017 19:58       1052       9636      253       NaN        Right
# 1  10/1/2017 22:43       1054       9637      254       NaN        Right
# 2  10/1/2017 22:50       1054       9637      255   RETWEET        Right
#
#   account_category
# 0       RightTroll
# 1       RightTroll
# 2       RightTroll

# %% [markdown]
# #### 1.1.2.3) Cleaning empty data and duplicates, plus some small format changes.

# %%
isna_columns = data1_filter_english.isna().any(axis=0)
column_nan_list = isna_columns[isna_columns== True].index.tolist()
for x in column_nan_list:
    print(x, ":", data1_filter_english[x].isnull().sum())
    #clean
# Out:
# content : 1
# region : 1145
# post_type : 1270631
# account_type : 354

# %% [markdown]
# For content we are going to eliminate the only empty one. For region and account_type, we are going to change it to an string that shows that it is unknown. When the post_type is nan, it only means that it is a original tweet so we change it to that.

# %%
data1_filter_english["account_type"] = data1_filter_english["account_type"].fillna("?") #gjøre om right til Right?
data1_filter_english["region"] = data1_filter_english["region"].fillna("Unknown")
data1_filter_english["content"] = data1_filter_english["content"].dropna()
data1_filter_english["post_type"] = data1_filter_english["post_type"].fillna("ORIGINAL")
#clea

# %%
#We also found out that there are two account_types that are equal. "Right" and "right". T
data1_filter_english["account_type"] = data1_filter_english["account_type"].str.lower()

# %% [markdown]
# The time stamps in this dataset is in string format. For further calculations, it would be better to have them as datetime.

# %%
data1_filter_english["publish_date"] = pd.to_datetime(data1_filter_english["publish_date"], format='%m/%d/%Y\n%H:%M')

# %%
data1_dup_step = data1_filter_english.drop_duplicates()
duplicates_number = data1_filter_english.shape[0]-data1_dup_step.shape[0] #må endres til data eller noe som er faktisk

dropdup_specific = data1_filter_english.drop_duplicates(subset= ["external_author_id", "content", "following", "followers", "updates", "post_type"])
duplicates_except_timestamp = data1_dup_step.shape[0]-dropdup_specific.shape[0]
print("Full duplicates:", duplicates_number, "\nDuplicates in all forms except time stamp:", duplicates_except_timestamp)
# Out:
# Full duplicates: 13692
# Duplicates in all forms except time stamp: 358

# %%
data1 = data1_filter_english.drop_duplicates(subset= ["external_author_id", "content", "following", "followers", "updates", "post_type"])
data1.head(4)
# Out:
#    external_author_id  author  \
# 0        9.060000e+17  10_GOP
# 1        9.060000e+17  10_GOP
# 2        9.060000e+17  10_GOP
# 3        9.060000e+17  10_GOP
#
#                                              content   region language  \
# 0  "We have a sitting Democrat US Senator on tria...  Unknown  English
# 1  Marshawn Lynch arrives to game in anti-Trump s...  Unknown  English
# 2  Daughter of fallen Navy Sailor delivers powerf...  Unknown  English
# 3  JUST IN: President Trump dedicates Presidents ...  Unknown  English
#
#          publish_date  following  followers  updates post_type account_type  \
# 0 2017-10-01 19:58:00       1052       9636      253  ORIGINAL        right
# 1 2017-10-01 22:43:00       1054       9637      254  ORIGINAL        right
# 2 2017-10-01 22:50:00       1054       9637      255   RETWEET        right
# 3 2017-10-01 23:52:00       1062       9642      256  ORIGINAL        right
#
#   account_category
# 0       RightTroll
# 1       RightTroll
# 2       RightTroll
# 3       RightTroll

# %% [markdown]
# ## 1.2) The second dataset
# Twitter released nine million tweets that they had traced to russian troll accounts on 17th October 2018. This dataset was in a much more raw format than the one provided on Kaggle, and consisted of eigth csv-files. Four of them was tweets from the Iranian agency, who also does this on a major scale. The other four was tweets produced by the IRA:
# - rus_troll_user.csv : Contains user specific features.
# - rus_troll_tweet_text.csv: Contains text and language of the given tweet.
# - rus_troll_tweet_metadata.csv: Contains features that are user specific, but may change tweet to tweet.
# - rus_troll_tweet_stats.csv: Contains other tweet features.
#
# The whole dataset can be downloaded at this link: https://drive.google.com/open?id=1GBsVXYvPrGcYI-wR4mWGO39fly1TMqjO.
#
# We are going to slim in the columns in this dataset a lot, as well as creating some new features.

# %% [markdown]
# ### 1.2.1) Loading the second dataset
# We loaded the second dataset in as pandas data frames as well. After that we merged all of them together, wrote the new frame as a parquet file and then read that as a spark file.

# %%
zip_file_new = ZipFile("New_russian_tweets.zip")
new_text = pd.read_csv(zip_file_new.open("rus_troll_tweet_text.csv"))
new_metadata = pd.read_csv(zip_file_new.open("rus_troll_tweet_metadata.csv")).drop(columns=["latitude","longitude","tweet_client_name"])
new_user = pd.read_csv(zip_file_new.open("rus_troll_user.csv")).drop(columns=["user_display_name","user_screen_name","user_profile_description","user_profile_url"])
new_stats = pd.read_csv(zip_file_new.open("rus_troll_tweet_stats.csv")).drop(columns=["poll_choices","urls"])

# %% [markdown]
# ### 1.2.1) Cleaning, merging and filtering the second dataset
#
# The data set did not have suitable column names, so we manually created column names under. We also merged all of the different files together, since we had dropped a bunch of columns which we found uninteresting.

# %%
new_text = new_text[new_text["tweet_language"]=="en"].drop(columns=["tweet_language"])
#To create a data frame that only had english tweets in it.
new_metadata.columns=["tweetid","following","followers"]

# %%
merge_step = pd.merge(new_text, new_metadata, on='tweetid')
new_tweets = pd.merge(merge_step,new_stats.filter(["tweetid","userid","tweet_time"]) , on='tweetid')

# %% [markdown]
# In the first data set we had a column that showed whether the tweet was original, retweet etc. The second set had not the same, so we wanted to create this.

# %%
retweets = new_stats[new_stats["is_retweet"]==True]
retweets = new_tweets[new_tweets["tweetid"].isin(retweets["tweetid"].tolist())]
retweets["post_type"] ="RETWEET"
quote_tweets = new_stats[np.isfinite(new_stats['quoted_tweet_tweetid'])]
quote_tweets = new_tweets[new_tweets["tweetid"].isin(quote_tweets["tweetid"].tolist())]
quote_tweets = quote_tweets[~quote_tweets["tweetid"].isin(retweets["tweetid"].tolist())]
quote_tweets["post_type"] = "QUOTE_TWEET"
unoriginal_tweets = quote_tweets.append(retweets)
orig_tweets= new_tweets[~new_tweets["tweetid"].isin(unoriginal_tweets["tweetid"])]
orig_tweets["post_type"] = "ORIGINAL_TWEET"
data2 = unoriginal_tweets.append(orig_tweets)

# kan du fylle ut denne med litt tekst grini.

# %% [markdown]
# The second dataset now have the following features:
# - tweetid | The ID of the tweet.
# - tweet_text | The text of the tweet
# - tweet_time | The date and time the tweet was sent
# - following | The number of accounts the handle was following at the time of the tweet
# - followers | The number of followers the handle had at the time of the tweet
# - user_id | The unique ID of the user who posted the tweet.
# - post_type | Indicates if the tweet was a retweet, original tweet or a quote-tweet.

# %% [markdown]
# # 2) An overview of the data.

# %% [markdown]
# ## 2.1) Enriching the data

# %%
data2
# Out:
#                     tweetid  \
# 12       653251376760295425
# 42       748448356297498626
# 199      815037019973763073
# 277      805940400229740545
# 346      786297829459308544
# 418      982420130746503168
# 420      995453435016335360
# 423      984169826578042882
# 564      700261387889721345
# 656      807510259325468672
# 960      795186787656278016
# 970      831686467797737472
# 1003     838316502201729024
# 1034     817428588576141312
# 1232     670033262912237568
# 1344     772429552966434821
# 1362     670032302622253056
# 1463     890841589253320709
# 1573     608814772419608576
# 1574     607968194267987970
# 1691     892204549964013568
# 1692     893843389791301632
# 1785     897687988863463424
# 1788     894432596985335808
# 1819     809665721340809216
# 1827     806320904712036352
# 1830     772475820178743296
# 1887     815086552455913472
# 2275     893575579764707329
# 2278     897007470496931840
# ...                     ...
# 3259572  620787477670854656
# 3259573  625685695290433536
# 3259576  737554480170831872
# 3259577  548742156366524416
# 3259578  556051412300230658
# 3259579  553516740823769088
# 3259580  555629344706801664
# 3259582  622512879938355200
# 3259583  627345993231695872
# 3259584  619007385537884160
# 3259586  616227547957854209
# 3259587  618673583527583744
# 3259588  622552721673994240
# 3259589  591117364504080384
# 3259601  720813919309172737
# 3259606  569070506814640128
# 3259607  531772835878821889
# 3259608  537540169868382209
# 3259609  576420049348534272
# 3259610  563020021161795585
# 3259611  547384181185994752
# 3259612  547783299196678146
# 3259613  553104593240862720
# 3259614  606149691256938496
# 3259615  659786027607851008
# 3259617  772444640897359872
# 3259619  557121679411789826
# 3259620  557160881629310976
# 3259621  557141291859865600
# 3259622  698581542965243906
#
#                                                 tweet_text  following  \
# 12               I need this skill https://t.co/2X4DHRVp2W      22035
# 42       Getting richer will provide our communities mo...      20019
# 199      Can't blame @realDonaldTrump for blocking you!...       2748
# 277      Damn, look at disgusting fatass @CBRangel... h...       2748
# 346      4 days and 5 hours left!  Take the poll!  http...       2748
# 418      Draft dodger vs war hero!  Your bet, Auntie? h...      34276
# 420      After a day of golfing he tells people to do t...      34276
# 423      Is it just me or they want a mole in DoJ? http...      34276
# 564      Great article!  #TCOT #CTOT #CCOT #ORPUW #PJNE...       1305
# 656      Let's pretend Russia leaked DNC &amp; Podesta ...       2748
# 960      Trump is with us so we can put an end to @Bara...       2748
# 970      .@NancyPelosi is dumber than dirt!  Ever heard...       2748
# 1003     There is something wrong with him.  Compare hi...       2748
# 1034     ...then you're an idiot... https://t.co/xT5Z9Y...       2748
# 1232     #DogThanking Toxication in NY on Thanksgiving....        107
# 1344     Will you? 😅😅😅 As for me, it is certainly not! ...      29472
# 1362     Sad decision – no #turkey meat, no problem. #K...         97
# 1463     #top RT Gregoriodownlow: Punishment for Espion...       1265
# 1573     Asec Perci Cendana NYC sees the BBL as a neces...         21
# 1574     Goals at some point live in NYC, Chicago, and ...         21
# 1691     RT RealJamesWoods: So the POTUS instantly reco...       1461
# 1692     realDonaldTrump = Honesty!BHO = Liar &amp; Tre...       1461
# 1785     RT americasloss: https://t.co/1genNusNmY https...        673
# 1788     RT terrymendozer: Rectal itching! I'm dying 😂😂...        673
# 1819     I don't mind presidential vacations at least f...       2748
# 1827     You're so gay, you're too stupid to believe @H...       2748
# 1830     Jimmy Carter is just a Democrat, and was terri...       2748
# 1887                      Fuck you https://t.co/gTEHZgBYIn       2748
# 2275     DonaldJTrumpJr what the heck is going on?? 😡😡😡...       1461
# 2278             Very interesting. https://t.co/4oRhhva2WH       1461
# ...                                                    ...        ...
# 3259572  http://t.co/7TiyLoiRu7 RT is my new workout pa...        791
# 3259573  http://t.co/3Fr1dxAKJh No man no gym Just jogg...        791
# 3259576  RT @VickiGP1: We don't need more elites tellin...       1812
# 3259577           By the time we've made it, we've had it.         98
# 3259578  #OscarForMuhammad He is the one who shed tears...        271
# 3259579    you seem to believe you belong to somebody else        271
# 3259580  Love is a game that two can play and both win....        271
# 3259582  http://t.co/VOhpmDAU5L If ya eyes aint burning...        377
# 3259583  http://t.co/frLUFMnoOH Literally in the workou...        377
# 3259584  http://t.co/XuszpwCmH1 Fb dash exchange exerci...        377
# 3259586  I'm sunburnt yall wearing a "12017 Obama's Las...        377
# 3259587  You don't exercise @Rumplestatskin @MundhenkSt...        377
# 3259588  http://t.co/vBdx8uinel I'm about to workout, I...        377
# 3259589  Bradley, Diamondbacks run away from Rangers  #...      18574
# 3259601  Friends of the Phoenix Public Library to donat...      18574
# 3259606  Those who don't believe in magic will never fi...        103
# 3259607  Never let a problem to be solved become more i...        496
# 3259608                      You're killing me, killing me        496
# 3259609  #local #news Peoria hosts Dog Day at spring-tr...      18574
# 3259610    National Signing Day 2015 live updates  #sports      18574
# 3259611  Peace is an unstable equilibrium, which can be...         28
# 3259612         If looks kill then you murderin'  – J.Cole         28
# 3259613  To the man who only has a hammer, everything h...         28
# 3259614  @HuskerStan @MichelleyM @NoompsyDahling @WestC...      28107
# 3259615                                  @LAmaleCA thanks!      28107
# 3259617              #ItsBestIfWe learn each other's names      28107
# 3259619  The trouble is not in dying for a friend, but ...        167
# 3259620                     Great souls endure in silence.        167
# 3259621  Learn how to be happy with what you have while...        167
# 3259622    Watch #COINTELPRO 101 (2010) online via DOCcupy       3074
#
#          followers                                             userid  \
# 12            9795                                         2882350436
# 42           14112                                         3978316814
# 199            265  a95a911dd6ae864c48ed062cdbe75e5c28dbe0cf57c6db...
# 277            265  a95a911dd6ae864c48ed062cdbe75e5c28dbe0cf57c6db...
# 346            265  a95a911dd6ae864c48ed062cdbe75e5c28dbe0cf57c6db...
# 3259583  2015-08-01 05:11  ORIGINAL_TWEET
# 3259584  2015-07-09 04:57  ORIGINAL_TWEET
# 3259586  2015-07-01 12:51  ORIGINAL_TWEET
# 3259587  2015-07-08 06:50  ORIGINAL_TWEET
# 3259588  2015-07-18 23:45  ORIGINAL_TWEET
# 3259589  2015-04-23 05:52  ORIGINAL_TWEET
# 3259601  2016-04-15 03:20  ORIGINAL_TWEET
# 3259606  2015-02-21 09:45  ORIGINAL_TWEET
# 3259607  2014-11-10 11:38  ORIGINAL_TWEET
# 3259608  2014-11-26 09:35  ORIGINAL_TWEET
# 3259609  2015-03-13 16:30  ORIGINAL_TWEET
# 3259610  2015-02-04 17:03  ORIGINAL_TWEET
# 3259611  2014-12-23 13:32  ORIGINAL_TWEET
# 3259612  2014-12-24 15:58  ORIGINAL_TWEET
# 3259613  2015-01-08 08:23  ORIGINAL_TWEET
# 3259614  2015-06-03 17:25  ORIGINAL_TWEET
# 3259615  2015-10-29 17:37  ORIGINAL_TWEET
# 3259617  2016-09-04 14:42  ORIGINAL_TWEET
# 3259619  2015-01-19 10:25  ORIGINAL_TWEET
# 3259620  2015-01-19 13:01  ORIGINAL_TWEET
# 3259621  2015-01-19 11:43  ORIGINAL_TWEET
# 3259622  2016-02-13 18:56  ORIGINAL_TWEET
#
# [3261931 rows x 7 columns]

# %% [markdown]
# ### 2.1.1) Creating new data frames

# %% [markdown]
# #### 2.1.x.x) Authors
# There are 2.1 million english tweets in this dataset but only a number of unique usernames. We want to take a look

# %%
authors = data1[["external_author_id", "author", "account_category"]].drop_duplicates(subset = "external_author_id")
authors = authors[authors.account_category != "NonEnglish"]
authors["tweet_count"] = data1.groupby('author')['author'].transform('count')
authors["peak_followers"] = data1.groupby(['author'], sort=True)['followers'].transform("max")
#authors["original_count]

# %%
most_pop_authors = authors.sort_values(by = "peak_followers", axis = 0)
most_pop_authors.tail(5)
# Out:
#          external_author_id           author account_category  tweet_count  \
# 684780         4.437234e+09  CRYSTAL1JOHNSON        LeftTroll         8037
# 935957         4.218156e+09       ELEVEN_GOP       RightTroll          101
# 2695290        2.752678e+09      TODAYNYCITY         NewsFeed        18478
# 2092783        4.272871e+09   PAMELA_MOORE13       RightTroll         6197
# 2599135        4.224730e+09          TEN_GOP       RightTroll        11274
#
#          peak_followers
# 684780            56725
# 935957            59100
# 2695290           62088
# 2092783           70734
# 2599135          145244

# %%
most_active_authors = authors.sort_values(by = "tweet_count", axis = 0).drop_duplicates(subset = ["author", "account_category", "tweet_count", "peak_followers"])
#For some reason, the author with the most tweets appeared with two different author IDs, and every other column was equal.
most_active_authors.tail(5)
# Out:
#          external_author_id           author account_category  tweet_count  \
# 2713824        2.601236e+09  TODAYPITTSBURGH         NewsFeed        33376
# 95228          1.679279e+09    AMELIEBALDWIN       RightTroll        34307
# 2872128        7.890000e+17    WORLDNEWSPOLI       RightTroll        35082
# 2399272        2.943515e+09    SCREAMYMONKEY         NewsFeed        43685
# 1008852        3.272641e+09          EXQUOTE       Commercial        53158
#
#          peak_followers
# 2713824           20608
# 1        Marshawn Lynch arrives to game in anti-Trump s...        Unknown
# 2        Daughter of fallen Navy Sailor delivers powerf...        Unknown
# 3        JUST IN: President Trump dedicates Presidents ...        Unknown
# 4        19,000 RESPECTING our National Anthem! #StandF...        Unknown
# 5        Dan Bongino: "Nobody trolls liberals better th...        Unknown
# 6                              🐝🐝🐝 https://t.co/MorL3AQW0z        Unknown
# 7        '@SenatorMenendez @CarmenYulinCruz Doesn't mat...        Unknown
# 8        As much as I hate promoting CNN article, here ...        Unknown
# 9        After the 'genocide' remark from San Juan Mayo...        Unknown
# 10       After the 'genocide' remark from San Juan Mayo...        Unknown
# 11       '@thehill Why won't she apologize to us for ly...        Unknown
# 12       Sarah Sanders destroys NBC reporter: "Trump ma...        Unknown
# 13       Hi @MichelleObama, remember when you said Wein...        Unknown
# 14       Hi @MichelleObama, remember when you praised H...        Unknown
# 15       Wow! Even CNN is slamming the Obamas for silen...        Unknown
# 16       First lady Melania Trump visits infant opioid ...        Unknown
# 17       BREAKING: The audio of sexual predator Harvey ...        Unknown
# 18                      '@Breaking911 Build that wall!! 👍'        Unknown
# 19       "It took Hillary abt 5 minutes to blame NRA fo...        Unknown
# 20       Because he hates women so much, President Trum...        Unknown
# 21       Congrats to Kirstjen Nielsen, our next Secreta...        Unknown
# 22       Pres. Trump: "We want lower taxes, bigger payc...        Unknown
# 23       I am an Eagle Scout   Only boys should be in B...        Unknown
# 24       This Eminem freestyle proves that celebs still...        Unknown
# 25       Do you agree with the Boy Scouts for allowing ...        Unknown
# 26       Pres. Trump just dropped a NUKE-truth-bomb: "T...        Unknown
# 27       Chief of Staff John Kelly destroys liberal rep...        Unknown
# 28       Network news has become so partisan, distorted...        Unknown
# 29       So we’ve gone from “Russia literally hacked th...        Unknown
# ...                                                    ...            ...
# 2935786  "Don't be like me, son. Be better..."  #Africa...  United States
# 2935787  Who said you had to be single just because she...  United States
# 2935788  Today on @TheEllenShow: my girl @JanelleMonae ...  United States
# 2935789  Lee Daniels on creating 'STAR': ‘I wanted whit...  United States
# 2935790  Review: @Gucci1017 Capped Off His "Hardest Wor...  United States
# 2935791  *playing 21 questions*  him: Whats your fav co...  United States
# 2935792                           Fry loved Leela soo much  United States
# 2935793  Dr. Carr gotta let me cook with these tweets!!...  United States
# 2935794  Wait a minute...so sinbad didn't play a genie ...  United States
# 2935795  If you, as a white person, can't say 'yes' to ...  United States
# 2935796  You say black people complain about racism too...  United States
# 2935797  If someone ever hacks @realDonaldTrump's twitt...  United States
# 2935798  Someone is in my mentions talmbout I need to t...  United States
# 2935799                 Dear Diary https://t.co/HNVw9f8ksv  United States
# 2935800        None of us can swim talmbout a nigger navy.  United States
# 2935801  Click, spin, &amp; flick! Twiddle Cube will ke...  United States
# 2935802  Breaking: At least three people dead in the Fo...  United States
# 2935803  Wayne Rooney gonna be the highest goal scorer ...  United States
# 2935804  Why The Walking Dead Is More Than A TV Show ht...  United States
# 2935805  My hometown newspaper. The St. Louis Post-Disp...  United States
# 2935806  Don't let anyone tell you he didn't have a sup...  United States
# 2935791  English 2017-01-05 07:29:00       2655       2726     3071   RETWEET
# 2935792  English 2017-01-05 07:29:00       2655       2726     3073   RETWEET
# 2935793  English 2017-01-05 07:29:00       2655       2726     3074   RETWEET
# 2935794  English 2017-01-05 07:29:00       2655       2726     3072   RETWEET
# 2935795  English 2017-01-06 13:42:00       2655       2724     3082   RETWEET
# 2935796  English 2017-01-06 13:42:00       2655       2724     3083   RETWEET
# 2935797  English 2017-01-06 13:42:00       2655       2724     3085   RETWEET
# 2935798  English 2017-01-06 13:42:00       2655       2724     3084   RETWEET
# 2935799  English 2017-01-06 19:43:00       2655       2724     3086   RETWEET
# 2935800  English 2017-01-06 19:43:00       2655       2724     3088   RETWEET
# 2935801  English 2017-01-06 19:43:00       2655       2724     3085   RETWEET
# 2935802  English 2017-01-06 19:43:00       2655       2724     3087   RETWEET
# 2935803  English 2017-01-07 13:51:00       2655       2724     3009   RETWEET
# 2935804  English 2017-01-07 13:51:00       2655       2724     3012   RETWEET
# 2935805  English 2017-01-07 13:51:00       2655       2724     3011   RETWEET
# 2935806  English 2017-01-07 13:51:00       2655       2724     3010   RETWEET
# 2935807  English 2017-01-07 01:45:00       2655       2723     3090   RETWEET
# 2935808  English 2017-01-07 01:45:00       2655       2724     3089   RETWEET
# 2935809  English 2017-01-07 01:46:00       2655       2724     3092   RETWEET
# 2935810  English 2017-01-07 01:46:00       2655       2724     3091   RETWEET
# 2935811  English 2017-01-07 07:47:00       2655       2724     3007   RETWEET
# 2935812  English 2017-01-07 07:47:00       2655       2724     3006   RETWEET
# 2935813  English 2017-01-07 07:47:00       2655       2724     3005   RETWEET
# 2935814  English 2017-01-07 07:48:00       2655       2724     3008   RETWEET
# 2935815  English 2017-01-08 01:56:00       2655       2724     3013   RETWEET
#
#         account_type account_category
# 0              right       RightTroll
# 1              right       RightTroll
# 2              right       RightTroll
# 3              right       RightTroll
# 4              right       RightTroll
# 5              right       RightTroll
# 6              right       RightTroll
# 7              right       RightTroll
# 8              right       RightTroll
# 9              right       RightTroll
# 10             right       RightTroll
# 11             right       RightTroll
# 12             right       RightTroll
# 13             right       RightTroll
# 14             right       RightTroll
# 15             right       RightTroll
# 16             right       RightTroll
# 17             right       RightTroll
# 18             right       RightTroll
# 19             right       RightTroll
# 20             right       RightTroll
# 21             right       RightTroll
# 22             right       RightTroll
# 23             right       RightTroll
# 24             right       RightTroll
# 25             right       RightTroll
# 26             right       RightTroll
# 27             right       RightTroll
# 28             right       RightTroll
# 29             right       RightTroll
# ...              ...              ...
# 2935786         left        LeftTroll
# 2935787         left        LeftTroll
# 2935788         left        LeftTroll
# 2935789         left        LeftTroll
# 2935790         left        LeftTroll
# 2935791         left        LeftTroll
# 2935792         left        LeftTroll
# 2935793         left        LeftTroll
# 2935794         left        LeftTroll
# 2935795         left        LeftTroll
# 2935796         left        LeftTroll
# 2935797         left        LeftTroll
# 2935798         left        LeftTroll
# 2935799         left        LeftTroll
# 2935800         left        LeftTroll
# 2935801         left        LeftTroll
# 2935802         left        LeftTroll
# 2935803         left        LeftTroll
# 2935804         left        LeftTroll
# 2935805         left        LeftTroll
# 2935806         left        LeftTroll
# 2935807         left        LeftTroll
# 2935808         left        LeftTroll
# 2935809         left        LeftTroll
# 2935810         left        LeftTroll
# 2935811         left        LeftTroll
# 2935812         left        LeftTroll
# 2935813         left        LeftTroll
# 2935814         left        LeftTroll
# 2935815         left        LeftTroll
#
# [1706720 rows x 12 columns]

# %% [markdown]
# #### 2.1.3.3 Data frames with different time periods

# %% [markdown]
# The first person that entered and started the primaries was Ted Cruz who officially entered the campaign on th 23th of March 2015. Hillary joined in as the first Democratic candidat on 12th April 2015. Donald Trump announced his candidacy on 16th June 2015.
#
# Therefore it is interesting to look at the amount of tweets from each side, starting with Ted Cruz' announcement. We have been looking into which party that has seen the most meddling, building up to the first primaries, the period between primaries and election and after the election.

# %%
before_primaries1 = data1.loc[data1["publish_date"] < "2016-06-14"]
before_primaries1 = before_primaries1.loc[before_primaries1["publish_date"] > "2015-03-23"]
before_primaries_time1 = before_primaries1["publish_date"].map(lambda x: str(x)[:7]).value_counts()
#left
before_primaries_left1 = before_primaries1.loc[before_primaries1["account_type"] == "left"]
bp_left_count1 = before_primaries_left1["publish_date"].map(lambda x: str(x)[:7]).value_counts()
#right
before_primaries_right1 = before_primaries1.loc[before_primaries1["account_type"] == "right"]
bp_right_count1 = before_primaries_right1["publish_date"].map(lambda x: str(x)[:7]).value_counts()

# %% [markdown]
# After the primaries, things changed. Now it was a run between Clinton and Trump.

# %%
after_primaries1 = data1.loc[data1["publish_date"] > "2016-06-14"]
after_primaries_time1 = after_primaries1["publish_date"].map(lambda x: str(x)[:7]).value_counts()
#left
after_primaries_left1 = after_primaries1.loc[after_primaries1["account_type"] == "left"]
ap_left_count1 = after_primaries_left1["publish_date"].map(lambda x: str(x)[:7]).value_counts()
#right
after_primaries_right1 = after_primaries1.loc[after_primaries1["account_type"] == "right"]
ap_right_count1 = after_primaries_right1["publish_date"].map(lambda x: str(x)[:7]).value_counts()

# %% [markdown]
# ## 2.2) Key takeaways from the data.

# %% [markdown]
# ### 2.2.1 Tweets over time
# How many tweets have been tweeted each month since the first russian troll tweet?

# %%
def name_axises(title, xlab, ylab):
    plt.title(title, size=22), plt.xlabel(xlab, size=20), plt.ylabel(ylab, size=20)
#A function for future plotting to save some lines.

data1_timesorted = data1.sort_values("publish_date")
data1_month_days = data1_timesorted["publish_date"].map(lambda x: str(x)[:7])
#if we want only month and days. 
data1_month_count = data1_month_days.value_counts()

fig, ax = plt.subplots()
figure(num=None, figsize=(15, 7), dpi=80, facecolor='w', edgecolor='k')
#ax.tick_params(labelsize=8)
over_time_fig = plt.bar(data1_month_count.index, data1_month_count, color = "#3CB371", align="center")
#for label in over_time_fig.ax.xaxis.get_ticklabels()[::2]:
    #label.set_visible(False)
name_axises("Tweets per month", "Time", "Number of tweets")

# %% [markdown]
# The results shows that there were almost no activity until the first candidates

# %%
data1_months = data1_timesorted["publish_date"].map(lambda x: str(x)[5:7])
data1_only_months = data1_months.value_counts().sort_index()

figure(num=None, figsize=(15, 7), dpi=80, facecolor='w', edgecolor='k')
#ax.tick_params(labelsize=8)
month_frequency = plt.bar(data1_only_months.index, data1_only_months, color = "#3CB371", align="center")
#if we want only month and days. 
#data1_month_count = data1_month_days.value_counts()

# %% [markdown]
# We can see that

# %%
data1_time_of_day = data1_timesorted["publish_date"].map(lambda x: str(x)[11:13])
data1_only_days = data1_time_of_day.value_counts().sort_index()

figure(num=None, figsize=(15, 7), dpi=80, facecolor='w', edgecolor='k')
#ax.tick_params(labelsize=8)
days_frequency = plt.bar(data1_only_days.index, data1_only_days, color = "#3CB371", align="center")
#days_frequency.grid()

# %% [markdown]
# This is the amount of tweets each hour in US time form

# %% [markdown]
# ### 2.2.x Different user and category stats

# %%
#ta mest aktive og mest fulgte. Sidestilt barchart med to stk

# %%
fig, ax = plt.subplots(1, 2, sharey=True)
fig.set_size_inches(17, 6)

sns.barplot(x="author", y="peak_followers", data=most_pop_authors.tail(10), ax=ax[0]).set_title("Most followers")
#plt.bar(most_pop_authors["author"], most_pop_authors["peak_followers"].tail(10), color = "#3CB371", align="center")
ax[0].set_xticklabels(most_pop_authors.tail(10)["author"], rotation=70)
## må fikses

sns.barplot(x="account_category", y="peak_followers", data=most_pop_authors.tail(10), ax=ax[1]).set_title("Most followers")
ax[1].set_xticklabels(most_pop_authors.tail(10)["account_category"], rotation=70)
# Out:
# [Text(0,0,'LeftTroll'), Text(0,0,'RightTroll'), Text(0,0,'RightTroll')]

# %% [markdown]
# # 3) Looking into specific research questions
# We found out that many of our initial research questions

# %% [markdown]
# ### 3.x What is up with the regions?

# %% [markdown]
# ### 3.x Did the troll activity change in regards to the american primaries?

# %% [markdown]
# **Before primaries:**

# %%
figure(num=None, figsize=(15, 7), dpi=80, facecolor='w', edgecolor='k')
plt.plot(before_primaries_time1.sort_index(), color = "#000000")
plt.plot(bp_left_count1.sort_index(), color = "#DE3A3A")
plt.plot(bp_right_count1.sort_index(), color = "#3549FD")
name_axises("Tweets per month", "Time", "Number of tweets")

figure(num=None, figsize=(15, 9), dpi=80, facecolor='w', edgecolor='k',)
plt.bar(before_primaries_time1.index, before_primaries_time1, color = "#000000")
plt.bar(bp_left_count1.index, bp_left_count1, color = "#DE3A3A")
plt.bar(bp_right_count1.index, bp_right_count1, color = "#3549FD")
name_axises("Tweets per month", "Time", "Number of tweets")

# %% [markdown]
# Things really started when the first people startet announcing their candidacy. In the beginning, after the first announced candidacy, it is almost an exponential growth of tweets. We can also see that it is a lot of tweets that are not political categorized as well. Let's have a small look at what happened in the month Hillary announced her candidacy.

# %%
hillary_month1 = data1.loc[data1["publish_date"] > "2015-04"]
hillary_month1 = hillary_month1.loc[hillary_month1["publish_date"] < "2015-05"]
hm_count1 = hillary_month1["publish_date"].map(lambda x: str(x)[8:10]).value_counts()
#left
hm_left1 = hillary_month1.loc[hillary_month1["account_type"] == "left"]
hm_left_count1 = hm_left1["publish_date"].map(lambda x: str(x)[8:10]).value_counts()
#right
hm_right1 = hillary_month1.loc[hillary_month1["account_type"] == "right"]
hm_right_count1 = hm_right1["publish_date"].map(lambda x: str(x)[8:10]).value_counts()

# %%
figure(num=None, figsize=(15, 7), dpi=80, facecolor='w', edgecolor='k')
plt.plot(hm_count1.sort_index(), color = "#000000", label = "Total tweets")
plt.plot(hm_left_count1.sort_index(), color = "#DE3A3A")
plt.plot(hm_right_count1.sort_index(), color = "#3549FD")
name_axises("Tweets per day the month Hillary announced her candidacy", "Time", "Number of tweets")

figure(num=None, figsize=(15, 9), dpi=80, facecolor='w', edgecolor='k',)
plt.bar(hm_count1.index, hm_count1, color = "#000000")
plt.bar(hm_left_count1.index, hm_left_count1, color = "#DE3A3A")
plt.bar(hm_right_count1.index, hm_right_count1, color = "#3549FD")
plt.legend(["j"])
plt.legend(["g"])
name_axises("Tweets per day the month Hillary announced her candidacy", "Time", "Number of tweets")

# %% [markdown]
# **After primaries**

# %%
figure(num=None, figsize=(15, 7), dpi=80, facecolor='w', edgecolor='k')
plt.plot(after_primaries_time1.sort_index(), color = "#000000",zorder=3)
plt.plot(ap_left_count1.sort_index(), color = "#DE3A3A",zorder=3)
plt.plot(ap_right_count1.sort_index(), color = "#3549FD",zorder=3)
name_axises("Tweets per month", "Time", "Number of tweets")

figure(num=None, figsize=(15, 9), dpi=80, facecolor='w', edgecolor='k',)
plt.bar(after_primaries_time1.index, after_primaries_time1, color = "#000000", zorder=3)
plt.bar(ap_left_count1.index, ap_left_count1, color = "#DE3A3A", zorder =3)
plt.bar(ap_right_count1.index, ap_right_count1, color = "#3549FD", zorder =3)
plt.grid(zorder=0)
name_axises("Tweets per month", "Time", "Number of tweets")

# %% [markdown]
# ### 3.x Are the trolls interacting with each other?

# %% [markdown]
# # 4) Discussion of our project so far

# %% [markdown]
# ## 4.1)

# %% [markdown]
# ## 4.2) Own thoughts of milestone 2

# %% [markdown]
# ### 4.2.1) Thoughts regarding the data sets
#
# **First dataset:**
#
# **Second dataset:**
#
# Things got a little changed when we got the possibility to work with a second data set on Sunday 18th November. The new data set featured a bunch of new interesting features, as well as not being categorized in the same manner as the first

# %% [markdown]
# ### 4.2.2) Dropped ideas
# **Other languages**
# We worked a while on trying to analyse some of the non-english tweets, in particular the european ones. It was a significant amount, especially of the german data, but we struggled to get something in particular out of it. In general text classification became harder than initially thought. We knew that the TextBlob library had the
#
# **

# %% [markdown]
# # 5) Plan for the next milestone

# %% [markdown]
# Visualization:
# - We are not pleased with the visualization at the moment, and want to increase our quality here.
# - Look for other alternatives than used right now or effectively improve those we already have.
# Modeling:
# - Try to create a model that could determine which category each twitter user is. This may be difficult to manage, but the idea is to split the original dataset into a training and test set and create a model that could classify the different categories.
# Perform the analysis regarding our most important research question -
# Improving the second data set:
# - Add features similar to the original data set.
# - Enrich the second data set by creating similar and new subsets.
# Create the data story:
# - Look for suitable tools to create our data story in.
# - Extract our most important findings and present something that actually provides meaningful insight to how the russian trolls operates.
# - Search for and add features unique for the data story. Animations e.g.
# - Finish the data story.
# Create the poster:
# - Sort out the visuals that works best in paper format, a
